# %% [markdown]
# # ASSIGNMENT 3 - Applied Data Science
# ## Hiya Kulasrestha - 20BCE2828
# ## Contact - 9971474317
# ## Email - kulasresthahiya@gmail.com
# ## VIT, Vellore

# %% [markdown]
# ### Problem Statement: House Price Prediction
#
# DESCRIPTION - House price prediction is a common problem in the real estate industry and involves predicting the selling price of a house based on various features and attributes. The problem is typically approached as a regression problem, where the target variable is the price of the house, and the features are various attributes of the house.
#
# The features used in house price prediction can include both quantitative and categorical variables, such as the number of bedrooms, house area, bedrooms, furnished, nearness to main road, and various amenities such as a garage and other factors that may influence the value of the property.
#
# Accurate predictions can help agents and appraisers price homes correctly, while homeowners can use the predictions to set a reasonable asking price for their properties. Accurate house price prediction can also be useful for buyers who are looking to make informed decisions about purchasing a property and obtaining a fair price for their investment.

# %% [markdown]
# ### Attribute Information:
#
# 1. Price - Prices of the houses
# 2. Area - Area of the houses
# 3. Bedrooms - No of house bedrooms
# 4. Bathrooms - No of bathrooms
# 5. Stories - No of house stories
# 6. Main Road - Whether connected to Main road
# 7. Guestroom - Whether has a guest room
# 8. Basement - Whether has a basement
# 9. Hot water heating - Whether has a hot water heater
# 10. Airconditioning - Whether has a air conditioner
# 11. Parking - No of house parking
# 12. Furnishing Status - Furnishing status of house

# %% [markdown]
# ### Perform Below Tasks to complete the assignment:-

# %%
# import the required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 1. Download the dataset
# ### 2. Load the dataset into the tool

# %%
#Load the dataset

data=pd.read_csv('Housing.csv')
data
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(6)
# memory usage: 51.2+ KB

# %%
data.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %% [markdown]
# ### 3. Perform Below Visualizations.
# ### ● Univariate Analysis
# ### ● Bi - Variate Analysis
# ### ● Multi - Variate Analysis

# %% [markdown]
# ### UNIVARIATE ANALYSIS

# %%
## histograms

print(plt.hist(data['bedrooms']))
plt.title('NO. OF BEDROOMS')
# Out:
# (array([  2.,   0., 136.,   0., 300.,   0.,  95.,   0.,  10.,   2.]), array([1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. , 5.5, 6. ]), <BarContainer object of 10 artists>)
# Text(0.5, 1.0, 'NO. OF BEDROOMS')

# %%
print(plt.hist(data['bathrooms']))
plt.title('NO. OF BATHROOMS')
# Out:
# (array([401.,   0.,   0., 133.,   0.,   0.,  10.,   0.,   0.,   1.]), array([1. , 1.3, 1.6, 1.9, 2.2, 2.5, 2.8, 3.1, 3.4, 3.7, 4. ]), <BarContainer object of 10 artists>)
# Text(0.5, 1.0, 'NO. OF BATHROOMS')

# %%
print(plt.hist(data['stories']))
plt.title('NO. OF STORIES')
# Out:
# (array([227.,   0.,   0., 238.,   0.,   0.,  39.,   0.,   0.,  41.]), array([1. , 1.3, 1.6, 1.9, 2.2, 2.5, 2.8, 3.1, 3.4, 3.7, 4. ]), <BarContainer object of 10 artists>)
# Text(0.5, 1.0, 'NO. OF STORIES')

# %%
print(plt.hist(data['parking']))
plt.title('NO. OF PARKING SLOTS')
# Out:
# (array([299.,   0.,   0., 126.,   0.,   0., 108.,   0.,   0.,  12.]), array([0. , 0.3, 0.6, 0.9, 1.2, 1.5, 1.8, 2.1, 2.4, 2.7, 3. ]), <BarContainer object of 10 artists>)
# Text(0.5, 1.0, 'NO. OF PARKING SLOTS')

# %%
## box plots

print(plt.boxplot(data['price']))
plt.title('PRICE')
# Out:
# {'whiskers': [<matplotlib.lines.Line2D object at 0x0000022734EBA530>, <matplotlib.lines.Line2D object at 0x0000022734EBA7D0>], 'caps': [<matplotlib.lines.Line2D object at 0x0000022734EBAA70>, <matplotlib.lines.Line2D object at 0x0000022734EBAD10>], 'boxes': [<matplotlib.lines.Line2D object at 0x0000022734EBA290>], 'medians': [<matplotlib.lines.Line2D object at 0x0000022734EBAFB0>], 'fliers': [<matplotlib.lines.Line2D object at 0x0000022734EBB250>], 'means': []}
# Text(0.5, 1.0, 'PRICE')

# %%
print(plt.boxplot(data['area']))
plt.title('AREA')
# Out:
# {'whiskers': [<matplotlib.lines.Line2D object at 0x0000022734F358A0>, <matplotlib.lines.Line2D object at 0x0000022734F35B40>], 'caps': [<matplotlib.lines.Line2D object at 0x0000022734F35DE0>, <matplotlib.lines.Line2D object at 0x0000022734F36080>], 'boxes': [<matplotlib.lines.Line2D object at 0x0000022734F35600>], 'medians': [<matplotlib.lines.Line2D object at 0x0000022734F36320>], 'fliers': [<matplotlib.lines.Line2D object at 0x0000022734F365C0>], 'means': []}
# Text(0.5, 1.0, 'AREA')

# %%
## pie charts

fs = data['furnishingstatus'].value_counts()
l1 = data['furnishingstatus'].unique()
plt.pie(fs, autopct='%.2f', labels = l1)
# Out:
# ([<matplotlib.patches.Wedge at 0x22734c69330>,
# ...
#  [Text(0.28521128309432414, 1.0623815340995388, 'furnished'),
#   Text(-0.9645476294288756, -0.5288174264934321, 'semi-furnished'),
#   Text(0.7608233961924185, -0.7944480850289933, 'unfurnished')],
#  [Text(0.15556979077872224, 0.5794808367815666, '41.65'),
#   Text(-0.5261168887793867, -0.2884458689964175, '32.66'),
#   Text(0.4149945797413191, -0.43333531910672357, '25.69')])

# %%
mr = data['mainroad'].value_counts()
l2 = data['mainroad'].unique()
plt.pie(mr, autopct='%.2f', labels = l2)
# Out:
# ([<matplotlib.patches.Wedge at 0x22734cc0970>,
# ...
#  [Text(-0.9934118007563487, 0.47236955248833384, 'yes'),
#   Text(0.9934118007563486, -0.47236955248833395, 'no')],
#  [Text(-0.5418609822307356, 0.2576561195390912, '85.87'),
#   Text(0.5418609822307355, -0.25765611953909123, '14.13')])

# %%
bs = data['basement'].value_counts()
l3 = data['basement'].unique()
plt.pie(bs, autopct='%.2f', labels = l3)
# Out:
# ([<matplotlib.patches.Wedge at 0x22734cf2fb0>,
# ...
#  [Text(-0.4979765227401237, 0.9808258677255892, 'no'),
#   Text(0.49797643090857663, -0.9808259143495117, 'yes')],
#  [Text(-0.27162355785824926, 0.5349959278503214, '64.95'),
#   Text(0.2716235077683145, -0.5349959532815518, '35.05')])

# %%
## bar plots

data['airconditioning'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
data['furnishingstatus'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
data['stories'].value_counts().plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# ### BIVARIATE ANALYSIS

# %%
# scatter plots

plt.scatter(data['area'], data['price'])
plt.title('AREA vs. PRICE')
# Out:
# Text(0.5, 1.0, 'AREA vs. PRICE')

# %%
## bar plots

plt.bar(data['parking'],data['area'])
plt.title('PARKING vs AREA')
# Out:
# Text(0.5, 1.0, 'PARKING vs AREA')

# %%
plt.bar(data['bedrooms'],data['price'])
plt.title('BEDROOMS vs PRICE')
# Out:
# Text(0.5, 1.0, 'BEDROOMS vs PRICE')

# %%
# line plots

plt.plot(data['price'],data['area'])
plt.title('PRICE vs AREA')
# Out:
# Text(0.5, 1.0, 'PRICE vs AREA')

# %% [markdown]
# ### MULTIVARIATE ANALYSIS

# %%
## heat maps

hm = data.corr()
sns.heatmap(hm)
# Out:
# C:\Users\Hiya Kulasrestha\AppData\Local\Temp\ipykernel_16972\3408337337.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   hm = data.corr()
# <Axes: >

# %%
#pair plots

sns.pairplot(data)

# %% [markdown]
# ### 4. Perform descriptive statistics on the dataset

# %%
data.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
## mean

data.mean()
# Out:
# C:\Users\Hiya Kulasrestha\AppData\Local\Temp\ipykernel_16972\696241312.py:3: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.mean()
# price        4.766729e+06
# area         5.150541e+03
# bedrooms     2.965138e+00
# bathrooms    1.286239e+00
# stories      1.805505e+00
# parking      6.935780e-01
# dtype: float64

# %%
## median

data.median()
# Out:
# C:\Users\Hiya Kulasrestha\AppData\Local\Temp\ipykernel_16972\1666824316.py:3: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.median()
# price        4340000.0
# area            4600.0
# bedrooms           3.0
# bathrooms          1.0
# stories            2.0
# parking            0.0
# dtype: float64

# %%
## mode 

data.mode()
# Out:
#      price    area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  3500000  6000.0       3.0        1.0      2.0      yes        no       no
# 1  4200000     NaN       NaN        NaN      NaN      NaN       NaN      NaN
#
#   hotwaterheating airconditioning  parking furnishingstatus
# 0              no              no      0.0   semi-furnished
# 1             NaN             NaN      NaN              NaN

# %%
## skewness

data.skew()
# Out:
# C:\Users\Hiya Kulasrestha\AppData\Local\Temp\ipykernel_16972\1290686286.py:3: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.skew()
# price        1.212239
# area         1.321188
# bedrooms     0.495684
# bathrooms    1.589264
# stories      1.082088
# parking      0.842062
# dtype: float64

# %%
## variance

data.var()
# Out:
# C:\Users\Hiya Kulasrestha\AppData\Local\Temp\ipykernel_16972\3753725857.py:3: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.var()
# price        3.498544e+12
# area         4.709512e+06
# bedrooms     5.447383e-01
# bathrooms    2.524757e-01
# stories      7.525432e-01
# parking      7.423300e-01
# dtype: float64

# %%
## standard deviation

data.std()
# Out:
# C:\Users\Hiya Kulasrestha\AppData\Local\Temp\ipykernel_16972\313374706.py:3: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.std()
# price        1.870440e+06
# area         2.170141e+03
# bedrooms     7.380639e-01
# bathrooms    5.024696e-01
# stories      8.674925e-01
# parking      8.615858e-01
# dtype: float64

# %%
## kurtosis

data.kurt()
# Out:
# C:\Users\Hiya Kulasrestha\AppData\Local\Temp\ipykernel_16972\1984645770.py:3: FutureWarning: The default value of numeric_only in DataFrame.kurt is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.kurt()
# price        1.960130
# area         2.751480
# bedrooms     0.728323
# bathrooms    2.164856
# stories      0.679404
# parking     -0.573063
# dtype: float64

# %%
## max values

data.max()
# Out:
# price                  13300000
# area                      16200
# bedrooms                      6
# bathrooms                     4
# stories                       4
# mainroad                    yes
# guestroom                   yes
# basement                    yes
# hotwaterheating             yes
# airconditioning             yes
# parking                       3
# furnishingstatus    unfurnished
# dtype: object

# %%
## min values

data.min()
# Out:
# price                 1750000
# area                     1650
# bedrooms                    1
# bathrooms                   1
# stories                     1
# mainroad                   no
# guestroom                  no
# basement                   no
# hotwaterheating            no
# airconditioning            no
# parking                     0
# furnishingstatus    furnished
# dtype: object

# %%
## inter quartile range (for area column)

quantile=data['area'].quantile(q=[0.75,0.25])
quantile
IQR=quantile.iloc[0]-quantile.iloc[1]
IQR
# Out:
# 2760.0

# %%
## inter quartile range (for price column)

quantile=data['price'].quantile(q=[0.75,0.25])
quantile
IQR=quantile.iloc[0]-quantile.iloc[1]
IQR
# Out:
# 2310000.0

# %% [markdown]
# ### 5. Handle the Missing values.

# %%
# checking the null values in dataset

data.isna()
# Out:
#      price   area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    False  False     False      False    False     False      False
# 1    False  False     False      False    False     False      False
# 2    False  False     False      False    False     False      False
# 3    False  False     False      False    False     False      False
# 4    False  False     False      False    False     False      False
# ..     ...    ...       ...        ...      ...       ...        ...
# 540  False  False     False      False    False     False      False
# 541  False  False     False      False    False     False      False
# 542  False  False     False      False    False     False      False
# 543  False  False     False      False    False     False      False
# 544  False  False     False      False    False     False      False
#
#      basement  hotwaterheating  airconditioning  parking  furnishingstatus
# ...

# %%
data.isnull().any()
# Out:
# price               False
# area                False
# bedrooms            False
# bathrooms           False
# stories             False
# mainroad            False
# guestroom           False
# basement            False
# hotwaterheating     False
# airconditioning     False
# parking             False
# furnishingstatus    False
# dtype: bool

# %%
data.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# furnishingstatus    0
# dtype: int64

# %%
## if we have null values in numerical column (age) we replace it with mean/median
## if we have null values in categorical column (embarked, deck, embark_town) we replace it with mode

## NO NULL VALUES FOUND

# %% [markdown]
# ### 6. Find the outliers and replace the outliers

# %%
## outlier detection

sns.boxplot(data.area)
# Out:
# <Axes: >

# %%
perc95 = data.area.quantile(0.95)

# %%
## outlier removal 

data = data[data.area<=perc95]
sns.boxplot(data.area)
# Out:
# <Axes: >

# %% [markdown]
# ### 7. Check for Categorical columns and perform encoding

# %%
## find categorical columns

catCols = data.select_dtypes("object").columns
catCols= list(set(catCols))
catCols
# Out:
# ['guestroom',
#  'hotwaterheating',
#  'mainroad',
#  'airconditioning',
#  'basement',
#  'furnishingstatus']

# %%
## perform encoding (label)

from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

for x in catCols:
    data[x] = le.fit_transform(data[x])
# Out:
# C:\Users\Hiya Kulasrestha\AppData\Local\Temp\ipykernel_16972\2731510984.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[x] = le.fit_transform(data[x])
# C:\Users\Hiya Kulasrestha\AppData\Local\Temp\ipykernel_16972\2731510984.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[x] = le.fit_transform(data[x])
# C:\Users\Hiya Kulasrestha\AppData\Local\Temp\ipykernel_16972\2731510984.py:8: SettingWithCopyWarning:
# ...

# %%
data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 3  12215000  7500         4          2        2         1          0
# 4  11410000  7420         4          1        2         1          1
# 5  10850000  7500         3          3        1         1          0
#
#    basement  hotwaterheating  airconditioning  parking  furnishingstatus
# 0         0                0                1        2                 0
# 1         0                0                1        3                 0
# 3         1                0                1        3                 0
# 4         1                0                1        2                 0
# 5         1                0                1        2                 1

# %% [markdown]
# ### 8. Split the data into dependent and independent variables

# %%
## y - dependent variable

y = data['price']
y.head()
# Out:
# 0    13300000
# 1    12250000
# 3    12215000
# 4    11410000
# 5    10850000
# Name: price, dtype: int64

# %%
## x - independent variables

x = data.drop(columns=['price'], axis=1)
x.head()
# Out:
#    area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 0  7420         4          2        3         1          0         0
# 1  8960         4          4        4         1          0         0
# 3  7500         4          2        2         1          0         1
# 4  7420         4          1        2         1          1         1
# 5  7500         3          3        1         1          0         1
#
#    hotwaterheating  airconditioning  parking  furnishingstatus
# 0                0                1        2                 0
# 1                0                1        3                 0
# 3                0                1        3                 0
# 4                0                1        2                 0
# 5                0                1        2                 1

# %% [markdown]
# ### 9. Scale the independent variables

# %%
## min-max scaling

from sklearn.preprocessing import MinMaxScaler

scale = MinMaxScaler()

name = x.columns
x_scaled = scale.fit_transform(x)
x = pd.DataFrame(x_scaled, columns=name)
x.head()
# Out:
#        area  bedrooms  bathrooms   stories  mainroad  guestroom  basement  \
# 0  0.785034       0.6   0.333333  0.666667       1.0        0.0       0.0
# 1  0.994558       0.6   1.000000  1.000000       1.0        0.0       0.0
# 2  0.795918       0.6   0.333333  0.333333       1.0        0.0       1.0
# 3  0.785034       0.6   0.000000  0.333333       1.0        1.0       1.0
# 4  0.795918       0.4   0.666667  0.000000       1.0        0.0       1.0
#
#    hotwaterheating  airconditioning   parking  furnishingstatus
# 0              0.0              1.0  0.666667               0.0
# 1              0.0              1.0  1.000000               0.0
# 2              0.0              1.0  1.000000               0.0
# 3              0.0              1.0  0.666667               0.0
# 4              0.0              1.0  0.666667               0.5

# %% [markdown]
# ### 10. Split the data into training and testing

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test=train_test_split(x, y, test_size=0.2, random_state=0)

# %%
X_train.head()
# Out:
#          area  bedrooms  bathrooms   stories  mainroad  guestroom  basement  \
# 374  0.578231       0.2   0.000000  0.000000       1.0        0.0       0.0
# 390  0.426531       0.4   0.000000  0.333333       1.0        1.0       1.0
# 56   0.591837       0.4   0.333333  0.333333       1.0        1.0       0.0
# 272  0.091837       0.4   0.000000  0.333333       0.0        0.0       0.0
# 60   0.983673       0.4   0.333333  0.333333       1.0        0.0       1.0
#
#      hotwaterheating  airconditioning   parking  furnishingstatus
# 374              0.0              0.0  0.333333               0.0
# 390              0.0              1.0  0.333333               0.0
# 56               0.0              0.0  0.333333               0.5
# 272              0.0              0.0  0.000000               0.5
# 60               0.0              1.0  0.333333               0.0

# %%
X_test.head()
# Out:
#          area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 422  0.251701       0.2   0.000000      0.0       0.0        0.0       1.0
# 107  0.714286       0.4   0.333333      0.0       1.0        1.0       1.0
# 253  0.324082       0.2   0.000000      0.0       1.0        0.0       1.0
# 235  0.897959       0.4   0.000000      0.0       1.0        0.0       0.0
# 311  0.223129       0.2   0.000000      0.0       1.0        0.0       0.0
#
#      hotwaterheating  airconditioning   parking  furnishingstatus
# 422              0.0              0.0  0.000000               0.5
# 107              0.0              0.0  0.000000               1.0
# 253              0.0              0.0  0.000000               0.0
# 235              0.0              0.0  0.000000               0.0
# 311              1.0              0.0  0.333333               0.0

# %%
y_train
# Out:
# 397    3500000
# 415    3395000
# 60     7140000
# 295    4200000
# 65     6930000
#         ...
# 77     6650000
# 300    4200000
# 12     9310000
# 382    3570000
# 209    4900000
# Name: price, Length: 416, dtype: int64

# %%
y_test
# Out:
# 447    3150000
# 116    6020000
# 275    4319000
# 257    4480000
# 334    3920000
#         ...
# 261    4473000
# 493    2800000
# 52     7350000
# 108    6107500
# 168    5250000
# Name: price, Length: 104, dtype: int64

# %% [markdown]
# ### 11. Build the Model

# %%
## model building - linear regression

from sklearn.linear_model import LinearRegression

lr = LinearRegression()

# %% [markdown]
# ### 12. Train the Model

# %%
## train the model 

lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### 13. Test the Model

# %%
## prediction

y_pred = lr.predict(X_test)
y_pred
# Out:
# array([ 2729433.67917101,  5606170.32243938,  3670276.84511424,
#         4860743.06697303,  4154188.09930246,  6697501.13622776,
#         5321832.34681929,  3390141.58051232,  2967277.89340012,
#         5288595.9306675 ,  3387809.36888418,  3596881.84622977,
#         5567323.08744598,  3510803.60913329,  3508824.52819953,
#         5096045.57363465,  4403895.89572   ,  5369019.98686532,
#         5830757.93831467,  5778732.29264375,  5907050.92849919,
#         6480905.32897776,  3093449.19981484,  3571686.320524  ,
#         3767378.81691739,  3665263.94074802,  5056729.72017895,
#         3602824.60580107,  4211553.95596275,  7735063.21796916,
#         6843377.77461912,  3852669.7295307 ,  4640907.07085954,
#         5020973.5234747 ,  4510034.88170335,  5320700.83315633,
#         4993001.69473743,  1970222.31213072,  3398522.10077534,
#         5122551.06730588,  5988392.17231965,  4165744.6303289 ,
#         3793860.50679936,  2175308.17597532,  4955457.47211027,
# ...

# %%
## actual outcome

y_test
# Out:
# 447    3150000
# 116    6020000
# 275    4319000
# 257    4480000
# 334    3920000
#         ...
# 261    4473000
# 493    2800000
# 52     7350000
# 108    6107500
# 168    5250000
# Name: price, Length: 104, dtype: int64

# %% [markdown]
# ### 14. Measure the performance using metrics

# %%
## error

E = y_test - y_pred
E
# Out:
# 447    4.205663e+05
# 116    4.138297e+05
# 275    6.487232e+05
# 257   -3.807431e+05
# 334   -2.341881e+05
#            ...
# 261    9.842987e+05
# 493   -6.321383e+05
# 52    -5.323143e+05
# 108    1.896799e+06
# 168   -2.892218e+04
# Name: price, Length: 104, dtype: float64

# %%
## r2 score

from sklearn.metrics import r2_score

acc = r2_score(y_pred,y_test)*100
acc
# Out:
# 47.603837886958054

# %%
## mean squared error

from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_test,y_pred)
mse
# Out:
# 1049916380070.129

# %%
## mean absolute error

from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(y_test,y_pred)
mae
# Out:
# 748234.917433023

# %%
## root mean squared error

rmse = np.sqrt(mse)
rmse
# Out:
# 1024654.2734357424
